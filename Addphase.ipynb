# %%
import Reader3 as Reader
from astropy.table import Table, Column
import numpy as np
import os
from astropy.io import fits
# Out:
# Using uproot:  5.3.10

# %% [markdown]
# # Add pulsar phase to DL3 FITS files
#
# by matching 'EVENT ID' with fully analyzed ROOT files containing phase information

# %%
fits_dir = '.' # Path to the directory containing DL3 FITS files
root_dir = '../data/all_root_data/' # Path to the directory containing melibea ROOT files with phase information

fits_files = [filename for filename in os.listdir(fits_dir) if filename.endswith('.fits')]
root_files = [filename for filename in os.listdir(root_dir) if filename.endswith('.root')]

# %%
def addphase(root_path, fits_path):
    root = Reader.Reader(root_path,{'daqnum':'MRawEvtHeader_2.fStereoEvtNumber','phase':'MPhase2_1.fPhase'})

    with fits.open(fits_path, mode='update') as hdulist:
        hdu_events = hdulist[1]
        fits_table = Table(hdu_events.data)

        if 'PHASE' in fits_table.colnames:
            print(f"Skipping fits file: {fits_path}. 'PHASE' column already exists.")
            hdulist.close()
            return
        
        id_to_val = {row['daqnum']: row['phase'] for row in root}

        phase_fits = np.full(len(fits_table), np.nan)

        for i, id in enumerate(fits_table['EVENT_ID']):
            if id in root['daqnum']:
                phase_fits[i] = id_to_val[id]

        new_col = fits.Column(name='PHASE', format='D', unit='', array=phase_fits)
        orig_cols = hdulist[1].data.columns
        combined = fits.BinTableHDU.from_columns(orig_cols + new_col)

        hdulist[1].data = combined.data
        hdulist.flush()

# %%
for fits_file in fits_files:
    if fits_file.endswith('.fits'):
        run = fits_file.split('_')[1]
        fits_path = os.path.join(fits_dir, fits_file)
        
        print(f"Processing fits file: {fits_path}")

        # search for corresponding root files
        found_root = False
        for root_file in root_files:
            root_run = root_file.split('_')[1].split('.')[0]
        
            if root_run == run:
                root_path = os.path.join(root_dir, root_file)
                found_root = True
                break
    
        if found_root:
            try:
                print(f"Corresponding root file: {root_path}")
                
                addphase(root_path, fits_path)
                
                print("Processing complete.", '\n')
                
            except Exception as e:
                print(f"Error processing files {fits_path}, {root_file}: {e}")

        else:
            print(f"No corresponding root file found for fits file: {fits_file}", '\n')
# Out:
# Processing fits file: ./20190207_05079628_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190207_05079628_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190207_05079628_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190207_05079628_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190207_05079628_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170123_05059990_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170123_05059990_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170123_05059990_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170123_05059990_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170123_05059990_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190131_05079298_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190131_05079298_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190131_05079298_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190131_05079298_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190131_05079298_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181111_05076724_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181111_05076724_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181111_05076724_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181111_05076724_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181111_05076724_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170201_05060425_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170201_05060425_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170201_05060425_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170201_05060425_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170201_05060425_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170131_05060395_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170131_05060395_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170131_05060395_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170131_05060395_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170131_05060395_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190103_05078275_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190103_05078275_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190103_05078275_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190103_05078275_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190103_05078275_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190209_05079738_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190209_05079738_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190209_05079738_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190209_05079738_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190209_05079738_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170127_05060182_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170127_05060182_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170127_05060182_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170127_05060182_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170127_05060182_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170123_05059991_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170123_05059991_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170123_05059991_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170123_05059991_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170123_05059991_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170123_05059993_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170123_05059993_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170123_05059993_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170123_05059993_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170123_05059993_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181210_05077489_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181210_05077489_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181210_05077489_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181210_05077489_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181210_05077489_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190227_05080202_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190227_05080202_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190227_05080202_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190227_05080202_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190227_05080202_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170226_05061515_DL3_Geminga-W0.40+270.fits
# Corresponding root file: ../data/all_data/20170226_05061515_Q_Geminga-W0.40+270.root
# Input : ('../data/all_data/20170226_05061515_Q_Geminga-W0.40+270.root',)
# Reading files from:  ../data/all_data/20170226_05061515_Q_Geminga-W0.40+270.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170226_05061515_Q_Geminga-W0.40+270.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170127_05060181_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170127_05060181_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170127_05060181_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170127_05060181_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170127_05060181_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190303_05080413_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190303_05080413_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190303_05080413_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190303_05080413_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190303_05080413_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181212_05077574_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181212_05077574_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181212_05077574_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181212_05077574_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181212_05077574_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181217_05077795_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181217_05077795_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181217_05077795_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181217_05077795_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181217_05077795_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170219_05061248_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170219_05061248_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170219_05061248_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170219_05061248_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170219_05061248_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170226_05061517_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170226_05061517_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170226_05061517_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170226_05061517_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170226_05061517_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181210_05077488_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181210_05077488_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181210_05077488_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181210_05077488_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181210_05077488_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190302_05080362_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190302_05080362_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190302_05080362_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190302_05080362_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190302_05080362_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170123_05059987_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170123_05059987_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170123_05059987_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170123_05059987_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170123_05059987_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190302_05080363_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190302_05080363_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190302_05080363_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190302_05080363_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190302_05080363_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190302_05080361_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190302_05080361_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190302_05080361_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190302_05080361_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190302_05080361_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190127_05079107_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190127_05079107_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190127_05079107_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190127_05079107_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190127_05079107_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190209_05079747_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190209_05079747_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190209_05079747_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190209_05079747_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190209_05079747_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190127_05079108_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190127_05079108_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190127_05079108_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190127_05079108_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190127_05079108_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181111_05076729_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181111_05076729_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181111_05076729_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181111_05076729_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181111_05076729_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170130_05060345_DL3_Geminga-W0.40+270.fits
# Corresponding root file: ../data/all_data/20170130_05060345_Q_Geminga-W0.40+270.root
# Input : ('../data/all_data/20170130_05060345_Q_Geminga-W0.40+270.root',)
# Reading files from:  ../data/all_data/20170130_05060345_Q_Geminga-W0.40+270.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170130_05060345_Q_Geminga-W0.40+270.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190228_05080247_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190228_05080247_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190228_05080247_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190228_05080247_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190228_05080247_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181111_05076727_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181111_05076727_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181111_05076727_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181111_05076727_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181111_05076727_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190204_05079473_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190204_05079473_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190204_05079473_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190204_05079473_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190204_05079473_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170125_05060083_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170125_05060083_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170125_05060083_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170125_05060083_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170125_05060083_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190303_05080416_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190303_05080416_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190303_05080416_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190303_05080416_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190303_05080416_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190227_05080204_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190227_05080204_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190227_05080204_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190227_05080204_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190227_05080204_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170127_05060186_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170127_05060186_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170127_05060186_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170127_05060186_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170127_05060186_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181216_05077756_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181216_05077756_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181216_05077756_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181216_05077756_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181216_05077756_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190112_05078712_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190112_05078712_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190112_05078712_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190112_05078712_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190112_05078712_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190131_05079297_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190131_05079297_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190131_05079297_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190131_05079297_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190131_05079297_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170130_05060344_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170130_05060344_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170130_05060344_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170130_05060344_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170130_05060344_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190201_05079349_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190201_05079349_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190201_05079349_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190201_05079349_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190201_05079349_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181213_05077628_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181213_05077628_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181213_05077628_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181213_05077628_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181213_05077628_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190228_05080248_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190228_05080248_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190228_05080248_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190228_05080248_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190228_05080248_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170131_05060390_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170131_05060390_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170131_05060390_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170131_05060390_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170131_05060390_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170227_05061567_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170227_05061567_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170227_05061567_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170227_05061567_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170227_05061567_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181204_05077253_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181204_05077253_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181204_05077253_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181204_05077253_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181204_05077253_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190206_05079577_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190206_05079577_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190206_05079577_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190206_05079577_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190206_05079577_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190208_05079685_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190208_05079685_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190208_05079685_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190208_05079685_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190208_05079685_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181210_05077487_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181210_05077487_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181210_05077487_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181210_05077487_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181210_05077487_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170124_05060042_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170124_05060042_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170124_05060042_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170124_05060042_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170124_05060042_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170125_05060098_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170125_05060098_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170125_05060098_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170125_05060098_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170125_05060098_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170127_05060183_DL3_Geminga-W0.40+270.fits
# Corresponding root file: ../data/all_data/20170127_05060183_Q_Geminga-W0.40+270.root
# Input : ('../data/all_data/20170127_05060183_Q_Geminga-W0.40+270.root',)
# Reading files from:  ../data/all_data/20170127_05060183_Q_Geminga-W0.40+270.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170127_05060183_Q_Geminga-W0.40+270.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170126_05060152_DL3_Geminga-W0.40+270.fits
# Corresponding root file: ../data/all_data/20170126_05060152_Q_Geminga-W0.40+270.root
# Input : ('../data/all_data/20170126_05060152_Q_Geminga-W0.40+270.root',)
# Reading files from:  ../data/all_data/20170126_05060152_Q_Geminga-W0.40+270.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170126_05060152_Q_Geminga-W0.40+270.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170216_05061037_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170216_05061037_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170216_05061037_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170216_05061037_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170216_05061037_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170123_05059986_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170123_05059986_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170123_05059986_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170123_05059986_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170123_05059986_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181213_05077625_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181213_05077625_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181213_05077625_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181213_05077625_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181213_05077625_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190302_05080365_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190302_05080365_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190302_05080365_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190302_05080365_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190302_05080365_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181111_05076725_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181111_05076725_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181111_05076725_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181111_05076725_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181111_05076725_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181212_05077579_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181212_05077579_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181212_05077579_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181212_05077579_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181212_05077579_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181214_05077664_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181214_05077664_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181214_05077664_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181214_05077664_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181214_05077664_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190201_05079346_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190201_05079346_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190201_05079346_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190201_05079346_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190201_05079346_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170220_05061298_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170220_05061298_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170220_05061298_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170220_05061298_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170220_05061298_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181110_05076682_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181110_05076682_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181110_05076682_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181110_05076682_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181110_05076682_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181109_05076640_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181109_05076640_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181109_05076640_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181109_05076640_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181109_05076640_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181108_05076598_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181108_05076598_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181108_05076598_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181108_05076598_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181108_05076598_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170130_05060341_DL3_Geminga-W0.40+270.fits
# Corresponding root file: ../data/all_data/20170130_05060341_Q_Geminga-W0.40+270.root
# Input : ('../data/all_data/20170130_05060341_Q_Geminga-W0.40+270.root',)
# Reading files from:  ../data/all_data/20170130_05060341_Q_Geminga-W0.40+270.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170130_05060341_Q_Geminga-W0.40+270.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181212_05077576_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181212_05077576_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181212_05077576_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181212_05077576_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181212_05077576_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170126_05060155_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170126_05060155_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170126_05060155_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170126_05060155_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170126_05060155_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181214_05077665_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181214_05077665_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181214_05077665_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181214_05077665_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181214_05077665_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170124_05060043_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170124_05060043_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170124_05060043_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170124_05060043_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170124_05060043_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170201_05060428_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170201_05060428_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170201_05060428_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170201_05060428_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170201_05060428_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190208_05079688_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190208_05079688_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190208_05079688_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190208_05079688_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190208_05079688_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190131_05079296_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190131_05079296_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190131_05079296_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190131_05079296_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190131_05079296_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170220_05061301_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170220_05061301_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170220_05061301_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170220_05061301_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170220_05061301_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190208_05079686_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190208_05079686_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190208_05079686_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190208_05079686_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190208_05079686_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170130_05060346_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170130_05060346_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170130_05060346_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170130_05060346_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170130_05060346_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181111_05076730_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181111_05076730_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181111_05076730_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181111_05076730_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181111_05076730_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190210_05079806_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190210_05079806_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190210_05079806_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190210_05079806_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190210_05079806_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190206_05079572_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190206_05079572_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190206_05079572_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190206_05079572_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190206_05079572_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190203_05079413_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190203_05079413_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190203_05079413_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190203_05079413_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190203_05079413_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170125_05060096_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170125_05060096_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170125_05060096_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170125_05060096_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170125_05060096_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190131_05079294_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190131_05079294_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190131_05079294_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190131_05079294_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190131_05079294_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170216_05061047_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170216_05061047_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170216_05061047_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170216_05061047_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170216_05061047_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190205_05079518_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190205_05079518_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190205_05079518_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190205_05079518_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190205_05079518_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190301_05080300_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190301_05080300_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190301_05080300_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190301_05080300_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190301_05080300_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181217_05077798_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181217_05077798_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181217_05077798_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181217_05077798_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181217_05077798_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190209_05079741_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190209_05079741_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190209_05079741_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190209_05079741_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190209_05079741_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170125_05060097_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170125_05060097_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170125_05060097_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170125_05060097_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170125_05060097_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181212_05077578_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181212_05077578_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181212_05077578_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181212_05077578_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181212_05077578_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181216_05077754_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181216_05077754_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181216_05077754_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181216_05077754_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181216_05077754_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181110_05076684_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181110_05076684_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181110_05076684_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181110_05076684_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181110_05076684_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190210_05079802_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190210_05079802_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190210_05079802_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190210_05079802_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190210_05079802_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# ...
#
# Processing fits file: ./20190208_05079689_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190208_05079689_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190208_05079689_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190208_05079689_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190208_05079689_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170129_05060292_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170129_05060292_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170129_05060292_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170129_05060292_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170129_05060292_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190109_05078561_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190109_05078561_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190109_05078561_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190109_05078561_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190109_05078561_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181108_05076599_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181108_05076599_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181108_05076599_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181108_05076599_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181108_05076599_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170227_05061564_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170227_05061564_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170227_05061564_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170227_05061564_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170227_05061564_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170129_05060287_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170129_05060287_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170129_05060287_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170129_05060287_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170129_05060287_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170201_05060427_DL3_Geminga-W0.40+270.fits
# Corresponding root file: ../data/all_data/20170201_05060427_Q_Geminga-W0.40+270.root
# Input : ('../data/all_data/20170201_05060427_Q_Geminga-W0.40+270.root',)
# Reading files from:  ../data/all_data/20170201_05060427_Q_Geminga-W0.40+270.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170201_05060427_Q_Geminga-W0.40+270.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190228_05080249_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190228_05080249_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190228_05080249_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190228_05080249_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190228_05080249_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190304_05080457_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190304_05080457_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190304_05080457_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190304_05080457_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190304_05080457_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170129_05060289_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170129_05060289_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170129_05060289_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170129_05060289_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170129_05060289_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170129_05060293_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170129_05060293_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170129_05060293_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170129_05060293_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170129_05060293_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181217_05077796_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181217_05077796_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181217_05077796_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181217_05077796_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181217_05077796_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181109_05076639_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181109_05076639_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181109_05076639_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181109_05076639_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181109_05076639_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181110_05076683_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181110_05076683_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181110_05076683_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181110_05076683_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181110_05076683_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190304_05080458_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190304_05080458_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190304_05080458_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190304_05080458_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190304_05080458_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170201_05060429_DL3_Geminga-W0.40+180.fits
# Corresponding root file: ../data/all_data/20170201_05060429_Q_Geminga-W0.40+180.root
# Input : ('../data/all_data/20170201_05060429_Q_Geminga-W0.40+180.root',)
# Reading files from:  ../data/all_data/20170201_05060429_Q_Geminga-W0.40+180.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170201_05060429_Q_Geminga-W0.40+180.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190207_05079623_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190207_05079623_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190207_05079623_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190207_05079623_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190207_05079623_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181211_05077534_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181211_05077534_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181211_05077534_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181211_05077534_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181211_05077534_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181212_05077582_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20181212_05077582_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20181212_05077582_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20181212_05077582_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181212_05077582_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181108_05076601_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181108_05076601_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181108_05076601_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181108_05076601_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181108_05076601_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190207_05079629_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190207_05079629_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190207_05079629_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190207_05079629_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190207_05079629_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190303_05080414_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190303_05080414_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190303_05080414_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190303_05080414_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190303_05080414_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190305_05080505_DL3_Geminga-W0.40+214.fits
# Corresponding root file: ../data/all_data/20190305_05080505_Q_Geminga-W0.40+214.root
# Input : ('../data/all_data/20190305_05080505_Q_Geminga-W0.40+214.root',)
# Reading files from:  ../data/all_data/20190305_05080505_Q_Geminga-W0.40+214.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190305_05080505_Q_Geminga-W0.40+214.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170226_05061516_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170226_05061516_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170226_05061516_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170226_05061516_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170226_05061516_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181214_05077666_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181214_05077666_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181214_05077666_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181214_05077666_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181214_05077666_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170201_05060426_DL3_Geminga-W0.40+090.fits
# Corresponding root file: ../data/all_data/20170201_05060426_Q_Geminga-W0.40+090.root
# Input : ('../data/all_data/20170201_05060426_Q_Geminga-W0.40+090.root',)
# Reading files from:  ../data/all_data/20170201_05060426_Q_Geminga-W0.40+090.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170201_05060426_Q_Geminga-W0.40+090.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190305_05080507_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190305_05080507_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190305_05080507_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190305_05080507_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190305_05080507_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20181212_05077583_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20181212_05077583_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20181212_05077583_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20181212_05077583_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20181212_05077583_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170123_05059985_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170123_05059985_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170123_05059985_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170123_05059985_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170123_05059985_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20170129_05060291_DL3_Geminga-W0.40+000.fits
# Corresponding root file: ../data/all_data/20170129_05060291_Q_Geminga-W0.40+000.root
# Input : ('../data/all_data/20170129_05060291_Q_Geminga-W0.40+000.root',)
# Reading files from:  ../data/all_data/20170129_05060291_Q_Geminga-W0.40+000.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20170129_05060291_Q_Geminga-W0.40+000.root ...  [1/1]
# Processing complete.
#
# Processing fits file: ./20190209_05079742_DL3_Geminga-W0.40+034.fits
# Corresponding root file: ../data/all_data/20190209_05079742_Q_Geminga-W0.40+034.root
# Input : ('../data/all_data/20190209_05079742_Q_Geminga-W0.40+034.root',)
# Reading files from:  ../data/all_data/20190209_05079742_Q_Geminga-W0.40+034.root
# Reading these elements:  (('daqnum', 'MRawEvtHeader_2.fStereoEvtNumber'), ('phase', 'MPhase2_1.fPhase'))
# Reading  ../data/all_data/20190209_05079742_Q_Geminga-W0.40+034.root ...  [1/1]
# Processing complete.
